# %%
import MeanRev_bt

# %%
test = MeanRev_bt.MeanRev_bt("GBPUSD",30, 2, "2018-01-01", "2019-12-30")

# %%
test
# Out:
# Mean Reversion Backtesting symbol = GBPUSD with SMA = 30, dev = 2, start = 2018-01-01, end = 2019-12-30, tc = 0

# %%
test.test_strategy()
# Out:
# (np.float64(1.005), np.float64(0.034))

# %%
test.plot_result()

# %%
test.optimize_strat((1,30), (1,5))
# Out:
# ((28, 3), np.float64(1.057))

# %%
test.result_overview
# Out:
#      SMA  dev  performance
# 0      1    1        1.000
# 1      1    2        1.000
# 2      1    3        1.000
# 3      1    4        1.000
# 4      2    1        1.000
# ..   ...  ...          ...
# 111   28    4        1.029
# 112   29    1        0.934
# 113   29    2        1.020
# 114   29    3        1.041
# 115   29    4        1.029
#
# [116 rows x 3 columns]

# %%
test.result_overview.nlargest(10, "performance")
# Out:
#      SMA  dev  performance
# 110   28    3        1.057
# 106   27    3        1.053
# 114   29    3        1.041
# 102   26    3        1.040
# 94    24    3        1.037
# 98    25    3        1.037
# 90    23    3        1.031
# 95    24    4        1.031
# 70    18    3        1.029
# 107   27    4        1.029

# %%
test.plot_result()
